# %% [markdown]
# This notebook demonstrates a simple proof-of-concept for creating nodes and relationships in a Neo4j database from a Python client

# %%
# !pip install py2neo -U
# Out:
# Requirement already up-to-date: py2neo in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied, skipping upgrade: neobolt~=1.7.12 in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (1.7.16)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (2019.3)
# Requirement already satisfied, skipping upgrade: click==7.0 in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (7.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.23 in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (1.24.2)
# Requirement already satisfied, skipping upgrade: certifi in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (2019.9.11)
# Requirement already satisfied, skipping upgrade: pygments~=2.3.1 in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (2.3.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit~=2.0.7 in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (2.0.10)
# Requirement already satisfied, skipping upgrade: colorama in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (0.4.1)
# Requirement already satisfied, skipping upgrade: neotime~=1.7.4 in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from py2neo) (1.7.4)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from prompt-toolkit~=2.0.7->py2neo) (1.12.0)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\jtotten\appdata\local\continuum\anaconda3\lib\site-packages (from prompt-toolkit~=2.0.7->py2neo) (0.1.7)

# %%
import pandas as pd
import py2neo
print(py2neo.__version__)
# Out:
# 4.3.0

# %%
# url = 'https://raw.githubusercontent.com/tottenjordan/neo4j/master/data/movie_metadata.csv' # full dataset
url = 'https://raw.githubusercontent.com/tottenjordan/neo4j/master/data/movies_sample.csv' # sample dataset
movies_raw = pd.read_csv(url, index_col=0)

print(movies_raw.shape)
movies_raw.head()
# Out:
# (50, 28)
#            director_name  num_critic_for_reviews  duration  \
# color
# Color      James Cameron                     723       178
# Color     Gore Verbinski                     302       169
# Color         Sam Mendes                     602       148
# Color  Christopher Nolan                     813       164
# Color     Andrew Stanton                     462       132
#
#        director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# color
# Color                        0                     855  Joel David Moore
# Color                      563                    1000     Orlando Bloom
# Color                        0                     161      Rory Kinnear
# Color                    22000                   23000    Christian Bale
# Color                      475                     530   Samantha Morton
#
#        actor_1_facebook_likes      gross                           genres  \
# color
# Color                    1000  760505847  Action|Adventure|Fantasy|Sci-Fi
# Color                   40000  309404152         Action|Adventure|Fantasy
# Color                   11000  200074175        Action|Adventure|Thriller
# Color                   27000  448130642                  Action|Thriller
# Color                     640   73058679          Action|Adventure|Sci-Fi
#
#           actor_1_name  ... language  country  content_rating     budget  \
# color                   ...
# Color      CCH Pounder  ...  English      USA           PG-13  237000000
# Color      Johnny Depp  ...  English      USA           PG-13  300000000
# Color  Christoph Waltz  ...  English       UK           PG-13  245000000
# Color        Tom Hardy  ...  English      USA           PG-13  250000000
# Color     Daryl Sabara  ...  English      USA           PG-13  263700000
#
#        title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# color
# Color        2009                    936        7.9          1.78
# Color        2007                   5000        7.1          2.35
# Color        2015                    393        6.8          2.35
# Color        2012                  23000        8.5          2.35
# Color        2012                    632        6.6          2.35
#
#       movie_facebook_likes                                         actors
# color
# Color                33000         CCH Pounder|Joel David Moore|Wes Studi
# Color                    0       Johnny Depp|Orlando Bloom|Jack Davenport
# Color                85000  Christoph Waltz|Rory Kinnear|Stephanie Sigman
# Color               164000  Tom Hardy|Christian Bale|Joseph Gordon-Levitt
# Color                24000      Daryl Sabara|Samantha Morton|Polly Walker
#
# [5 rows x 28 columns]

# %% [markdown]
# For this exercise:
# * Drop null values
# * Combine actor columns

# %%
# create movies df excluding nulls
movies_df = movies_raw.dropna(axis=0, how='any').copy()

# combine actors
movies_df['actors'] = movies_df['actor_1_name'] + "|" + movies_df['actor_2_name'] + "|" + movies_df['actor_3_name']

print(movies_df.shape)
movies_df.head()
# Out:
# (50, 28)
#            director_name  num_critic_for_reviews  duration  \
# color
# Color      James Cameron                     723       178
# Color     Gore Verbinski                     302       169
# Color         Sam Mendes                     602       148
# Color  Christopher Nolan                     813       164
# Color     Andrew Stanton                     462       132
#
#        director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# color
# Color                        0                     855  Joel David Moore
# Color                      563                    1000     Orlando Bloom
# Color                        0                     161      Rory Kinnear
# Color                    22000                   23000    Christian Bale
# Color                      475                     530   Samantha Morton
#
#        actor_1_facebook_likes      gross                           genres  \
# color
# Color                    1000  760505847  Action|Adventure|Fantasy|Sci-Fi
# Color                   40000  309404152         Action|Adventure|Fantasy
# Color                   11000  200074175        Action|Adventure|Thriller
# Color                   27000  448130642                  Action|Thriller
# Color                     640   73058679          Action|Adventure|Sci-Fi
#
#           actor_1_name  ... language  country  content_rating     budget  \
# color                   ...
# Color      CCH Pounder  ...  English      USA           PG-13  237000000
# Color      Johnny Depp  ...  English      USA           PG-13  300000000
# Color  Christoph Waltz  ...  English       UK           PG-13  245000000
# Color        Tom Hardy  ...  English      USA           PG-13  250000000
# Color     Daryl Sabara  ...  English      USA           PG-13  263700000
#
#        title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# color
# Color        2009                    936        7.9          1.78
# Color        2007                   5000        7.1          2.35
# Color        2015                    393        6.8          2.35
# Color        2012                  23000        8.5          2.35
# Color        2012                    632        6.6          2.35
#
#       movie_facebook_likes                                         actors
# color
# Color                33000         CCH Pounder|Joel David Moore|Wes Studi
# Color                    0       Johnny Depp|Orlando Bloom|Jack Davenport
# Color                85000  Christoph Waltz|Rory Kinnear|Stephanie Sigman
# Color               164000  Tom Hardy|Christian Bale|Joseph Gordon-Levitt
# Color                24000      Daryl Sabara|Samantha Morton|Polly Walker
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Simple Update Ops
# * Test ability to upload data to graph data model
# * Create nodes
# * Create node properties
# * Create relationships between nodes

# %%
from py2neo import Graph

# Connect to Neo graph instance
graph = Graph("bolt://localhost:7687", user="neo4j", password="password")

# %% [markdown]
# ### Create Graph: Nodes

# %%
from py2neo import Node

# create movies nodes
for i in range(movies_df.shape[0]):
    title = movies_df.iloc[i, :]['movie_title']
    duration = int(movies_df.iloc[i, :]['duration'])
    gross = int(movies_df.iloc[i, :]['gross'])
    language = movies_df.iloc[i, :]['language']
    budget = int(movies_df.iloc[i, :]['budget'])
    usersCount = int(movies_df.iloc[i, :]['num_user_for_reviews'])
    imdbScore = movies_df.iloc[i, :]['imdb_score']
    movieFbLikes = int(movies_df.iloc[i, :]['movie_facebook_likes'])
    
    node = Node("Movie",
                title = title,
                duration = duration,
                gross = gross,
                language = language,
                budget = budget,
                usersCount = usersCount,
                imdbScore = imdbScore,
                moveiFbLikes = movieFbLikes
               )
  
    graph.create(node)

print('Movie nodes successfully created!')
# Out:
# Movie nodes successfully created!

# %%
# create plot nodes
all_plots = set()
for i in range(movies_df.shape[0]):
    plot_list = movies_df.iloc[i, :]['plot_keywords'].split("|")
    for plot in plot_list:
        all_plots.add(plot)

for plot in all_plots:
    node = Node("Plot", name=plot)
    graph.create(node)

print("Plot nodes successfully created!")
# Out:
# Plot nodes successfully created!

# %%
# create director nodes
all_directors = set()
for i in range(movies_df.shape[0]):
    director = movies_df.iloc[i, :]['director_name']
    all_directors.add(director)
        
for director in all_directors:
    node = Node("Director", name = director)
    graph.create(node)

print("Director nodes successfully created!")
# Out:
# Director nodes successfully created!

# %%
# create genre nodes
all_genres = set()
for i in range(movies_df.shape[0]):
    genre_list = movies_df.iloc[i, :]['genres'].split("|")
    for genre in genre_list:
        all_genres.add(genre)

for genre in all_genres:
    node = Node("Genre", name=genre)
    graph.create(node)

print("Genre nodes successfully created!")
# Out:
# Genre nodes successfully created!

# %%
# create actors nodes
all_actors = set()
for i in range(movies_df.shape[0]):
    actor_list = movies_df.iloc[i, :]['actors'].split("|")
    for actor in actor_list:
        all_actors.add(actor)

for actor in all_actors:
    node = Node("Actor",name=actor)
    graph.create(node)

print("Actor nodes successfully created!")
# Out:
# Actor nodes successfully created!

# %% [markdown]
# ### Create Graph: Relationships

# %%
from py2neo import NodeMatcher, Relationship

# Actors
for i in range(movies_df.shape[0]):
    title = movies_df.iloc[i, :]['movie_title']
    matcher = NodeMatcher(graph)
    movie_node = matcher.match("Movie", title=title).first()
    
    actors = movies_df.iloc[i, :]['actors'].split("|")
    for actor in actors:
        actor_node = matcher.match("Actor", name=actor).first()
        relationship = Relationship(actor_node, "ACTED_IN", movie_node)
        graph.create(relationship)
        
print("Relationships successfully created!")
# Out:
# Relationships successfully created!

# %%
# Genres
for i in range(movies_df.shape[0]):
    title = movies_df.iloc[i, :]['movie_title']
    matcher = NodeMatcher(graph)
    movie_node = matcher.match("Movie", title=title).first()
        
    genres = movies_df.iloc[i, :]['genres'].split("|")
    for genre in genres:
        genre_node = matcher.match("Genre", name=genre).first()
        relationship = Relationship(movie_node, "IN_GENRE", genre_node)
        graph.create(relationship)

print("Relationships created successfully!")
# Out:
# Relationships created successfully!

# %%
# Plots
for i in range(movies_df.shape[0]):
    title = movies_df.iloc[i, :]['movie_title']
    matcher = NodeMatcher(graph)
    movie_node = matcher.match("Movie", title=title).first()
    
    plots = movies_df.iloc[i, :]['plot_keywords'].split("|")
    for plot in plots:
        plot_node = matcher.match("Plot", name=plot).first()
        relationship = Relationship(movie_node, "HAS_PLOT", plot_node)
        graph.create(relationship)        

print("Relationships created successfully!")
# Out:
# Relationships created successfully!

# %%
# Directors
for i in range(movies_df.shape[0]):
    title = movies_df.iloc[i, :]['movie_title']
    matcher = NodeMatcher(graph)
    movie_node = matcher.match("Movie", title=title).first()
    
    director = movies_df.iloc[i, :]['director_name']
    director_node = matcher.match("Director", name=director).first()
    relationship = Relationship(director_node, "DIRECTED", movie_node)
    graph.create(relationship)       
        

print("Relationships created successfully!")
# Out:
# Relationships created successfully!
